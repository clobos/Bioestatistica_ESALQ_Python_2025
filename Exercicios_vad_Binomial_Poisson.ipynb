# %% [markdown]
# <a href="https://colab.research.google.com/github/clobos/Bioestatistica_ESALQ_Python_2025/blob/main/Exercicios_vad_Binomial_Poisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXERCÍCIOS - VARIÁVEIS ALEATÓRIAS DISCRETAS
#
#
#  Para cada exercício, você deve:
#
#  1. Verificar se a função é uma função de massa de probabilidade
#  2. Criar tabela da distribuição da variável aleatória
#  3. Fazer gráfico da função de probabilidades
#  4. Fazer gráfico da função de distribuição acumulada
#  5. Calcular valor esperado (E[X])
#  6. Calcular variância (Var[X])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

# %%
# ==========================================
# EXERCÍCIO 1
# ==========================================
# Contexto: Número de ovos viáveis em ninhada de ave
# Uma ave põe 3 ovos. Seja X = número de ovos viáveis.
# Função dada: P(X = k) = (3! / (k! * (3-k)!)) * (0.8)^k * (0.2)^(3-k)
# para k = 0, 1, 2, 3

print("EXERCÍCIO 1: Ovos viáveis em ninhada")
x_vals = [0, 1, 2, 3]
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 2
# ==========================================
# Contexto: Número de mutações em gene
# Em um gene, seja X = número de mutações detectadas.
# Valores possíveis: 0, 1, 2, 3, 4
# Probabilidades: P(X=0)=0.4, P(X=1)=0.3, P(X=2)=0.2, P(X=3)=0.08, P(X=4)=0.02

print("\nEXERCÍCIO 2: Mutações em gene")
x_vals = [0, 1, 2, 3, 4]
probabilities = [0.4, 0.3, 0.2, 0.08, 0.02]
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 3
# ==========================================
# Contexto: Número de filhotes sobreviventes
# Uma fêmea de roedor tem 4 filhotes. X = número de sobreviventes após 1 mês.
# P(X = k) = C(4,k) * (0.75)^k * (0.25)^(4-k) para k = 0, 1, 2, 3, 4

print("\nEXERCÍCIO 3: Sobrevivência de filhotes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 4
# ==========================================
# Contexto: Número de células infectadas por vírus
# Em uma cultura com 5 células, X = número de células infectadas.
# P(X=0)=0.32, P(X=1)=0.40, P(X=2)=0.20, P(X=3)=0.06, P(X=4)=0.015, P(X=5)=0.005

print("\nEXERCÍCIO 4: Células infectadas")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 5
# ==========================================
# Contexto: Número de espécies encontradas em amostra
# Em uma amostra de solo, X = número de espécies de fungos encontradas.
# X pode assumir valores: 1, 2, 3, 4, 5
# P(X=1)=0.1, P(X=2)=0.25, P(X=3)=0.35, P(X=4)=0.25, P(X=5)=0.05

print("\nEXERCÍCIO 5: Espécies de fungos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 6
# ==========================================
# Contexto: Número de parasitas por peixe
# Em peixes de um lago, X = número de parasitas por indivíduo.
# X ∈ {0, 1, 2, 3, 4, 5}
# P(X=k) = 0.2 * (0.8)^k para k = 0, 1, 2, 3, 4
# P(X=5) = 1 - ∑P(X=k) para k=0 até 4

print("\nEXERCÍCIO 6: Parasitas por peixe")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 7
# ==========================================
# Contexto: Número de flores por planta
# Uma planta pode produzir 0, 1, 2, 3 ou 4 flores.
# P(X=0)=0.05, P(X=1)=0.15, P(X=2)=0.30, P(X=3)=0.35, P(X=4)=0.15

print("\nEXERCÍCIO 7: Flores por planta")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 8
# ==========================================
# Contexto: Número de cromossomos com aberração
# Em análise citogenética, X = número de cromossomos com aberração (0 a 6).
# P(X=k) = C(6,k) * (0.1)^k * (0.9)^(6-k)

print("\nEXERCÍCIO 8: Cromossomos com aberração")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 9
# ==========================================
# Contexto: Número de seedlings emergentes
# Em teste de germinação com 7 sementes, X = número de seedlings emergentes.
# P(X=k) = (7!)/(k!(7-k)!) * (0.6)^k * (0.4)^(7-k)

print("\nEXERCÍCIO 9: Seedlings emergentes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 10
# ==========================================
# Contexto: Número de predadores avistados
# Durante observação de 1 hora, X = número de predadores avistados.
# X ∈ {0, 1, 2, 3}
# P(X=0)=0.6, P(X=1)=0.3, P(X=2)=0.08, P(X=3)=0.02

print("\nEXERCÍCIO 10: Predadores avistados")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 11
# ==========================================
# Contexto: Número de tumores benignos
# Em análise histológica, X = número de tumores benignos detectados (0 a 4).
# P(X=k) = (e^(-1.5) * 1.5^k) / k! para k = 0, 1, 2, 3, 4

print("\nEXERCÍCIO 11: Tumores benignos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 12
# ==========================================
# Contexto: Número de reações positivas
# Em teste alérgico com 8 substâncias, X = número de reações positivas.
# P(X=k) = C(8,k) * (0.25)^k * (0.75)^(8-k)

print("\nEXERCÍCIO 12: Reações alérgicas positivas")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 13
# ==========================================
# Contexto: Número de brotos por estaca
# Em propagação vegetativa, X = número de brotos por estaca.
# X ∈ {0, 1, 2, 3, 4, 5}
# P(X=k) = (2^k * e^(-2)) / k! para k = 0, 1, 2, 3, 4, 5

print("\nEXERCÍCIO 13: Brotos por estaca")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 14
# ==========================================
# Contexto: Número de antibióticos eficazes
# Testando 5 antibióticos, X = número de antibióticos eficazes contra bactéria.
# P(X=0)=0.01, P(X=1)=0.05, P(X=2)=0.14, P(X=3)=0.30, P(X=4)=0.35, P(X=5)=0.15

print("\nEXERCÍCIO 14: Antibióticos eficazes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 15
# ==========================================
# Contexto: Número de galhos principais
# Uma árvore jovem pode ter de 2 a 6 galhos principais.
# P(X=2)=0.1, P(X=3)=0.2, P(X=4)=0.4, P(X=5)=0.25, P(X=6)=0.05

print("\nEXERCÍCIO 15: Galhos principais")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 16
# ==========================================
# Contexto: Número de colônias resistentes
# Em placa com 10 colônias, X = número de colônias resistentes a antibiótico.
# P(X=k) = C(10,k) * (0.3)^k * (0.7)^(10-k)

print("\nEXERCÍCIO 16: Colônias resistentes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 17
# ==========================================
# Contexto: Número de eritrócitos anômalos
# Em campo microscópico, X = número de eritrócitos anômalos observados.
# X ∈ {0, 1, 2, 3, 4}
# P(X=k) = (0.8^k * e^(-0.8)) / k!

print("\nEXERCÍCIO 17: Eritrócitos anômalos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 18
# ==========================================
# Contexto: Número de frutos por inflorescência
# Uma inflorescência pode produzir 1 a 5 frutos.
# P(X=k) = k/15 para k = 1, 2, 3, 4, 5

print("\nEXERCÍCIO 18: Frutos por inflorescência")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 19
# ==========================================
# Contexto: Número de leucócitos atípicos
# Em amostra sanguínea, X = número de leucócitos atípicos (0 a 7).
# P(X=k) = C(7,k) * (0.15)^k * (0.85)^(7-k)

print("\nEXERCÍCIO 19: Leucócitos atípicos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 20
# ==========================================
# Contexto: Número de nódulos radiculares
# Em leguminosa, X = número de nódulos radiculares com bactérias fixadoras.
# X ∈ {0, 1, 2, 3, 4, 5, 6}
# P(X=k) = (3^k * e^(-3)) / k! para k = 0, 1, 2, 3, 4, 5, 6

print("\nEXERCÍCIO 20: Nódulos radiculares")
# Complete o exercício aqui

# %% [markdown]
# # EXERCÍCIOS - DISTRIBUIÇÃO BINOMIAL
#
#  Para cada exercício sobre distribuição binomial, você deve:
#
#  1. Identificar os parâmetros n e p
#  2. Verificar se satisfaz as condições da binomial
#  3. Criar tabela da distribuição
#  4. Fazer gráfico da função de probabilidades
#  5. Fazer gráfico da função de distribuição acumulada
#  6. Calcular E[X] = np e Var[X] = np(1-p)
#  7. Responder perguntas específicas sobre probabilidades

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

# ==========================================
# EXERCÍCIO 1 - BINOMIAL
# ==========================================
# Contexto: Germinação de sementes de girassol
# Um lote contém sementes com 85% de taxa de germinação.
# Plantamos 12 sementes. X = número de sementes que germinam.
# Perguntas:
# a) Qual a probabilidade de exatamente 10 germinarem?
# b) Qual a probabilidade de pelo menos 8 germinarem?
# c) Quantas sementes esperamos que germinem?

print("EXERCÍCIO 1: Germinação de sementes")
n = 12
p = 0.85
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 2 - BINOMIAL
# ==========================================
# Contexto: Sobrevivência de filhotes de tartaruga
# Filhotes de tartaruga marinha têm 60% de chance de chegar ao mar.
# Uma ninhada tem 15 filhotes. X = número que chega ao mar.
# Perguntas:
# a) P(exatamente 9 chegam ao mar) = ?
# b) P(menos de 5 chegam ao mar) = ?
# c) Qual o número mais provável de sobreviventes?

print("\nEXERCÍCIO 2: Sobrevivência de filhotes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 3 - BINOMIAL
# ==========================================
# Contexto: Teste de medicamento veterinário
# Um medicamento tem 75% de eficácia em cães.
# Testamos em 20 cães. X = número de cães curados.
# Perguntas:
# a) P(todos os 20 serem curados) = ?
# b) P(pelo menos 18 serem curados) = ?
# c) Entre que valores esperamos 95% dos resultados?

print("\nEXERCÍCIO 3: Eficácia de medicamento")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 4 - BINOMIAL
# ==========================================
# Contexto: Sexo de filhotes em mamíferos
# Em uma espécie, probabilidade de nascer macho = 0.52.
# Uma fêmea tem 8 filhotes. X = número de machos.
# Perguntas:
# a) P(número igual de machos e fêmeas) = ?
# b) P(mais machos que fêmeas) = ?
# c) Qual a variância do número de machos?

print("\nEXERCÍCIO 4: Sexo de filhotes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 5 - BINOMIAL
# ==========================================
# Contexto: Floração de orquídeas
# Orquídeas cultivadas têm 40% de chance de florescer no primeiro ano.
# Um orquidário tem 25 plantas jovens. X = número que floresce.
# Perguntas:
# a) P(nenhuma florescer) = ?
# b) P(entre 8 e 12 florescerem) = ?
# c) Qual o desvio padrão esperado?

print("\nEXERCÍCIO 5: Floração de orquídeas")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 6 - BINOMIAL
# ==========================================
# Contexto: Resistência a pesticida
# 30% das pragas de uma região são resistentes a um pesticida.
# Coletamos 18 indivíduos. X = número de resistentes.
# Perguntas:
# a) P(exatamente 6 serem resistentes) = ?
# b) P(mais de 10 serem resistentes) = ?
# c) Qual o número esperado de susceptíveis?

print("\nEXERCÍCIO 6: Resistência a pesticida")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 7 - BINOMIAL
# ==========================================
# Contexto: Enxerto de plantas
# Em enxertia de citros, 80% dos enxertos são bem-sucedidos.
# Um viveiro faz 30 enxertos. X = número de sucessos.
# Perguntas:
# a) P(todos serem bem-sucedidos) = ?
# b) P(pelo menos 25 serem bem-sucedidos) = ?
# c) Qual a probabilidade de ter entre 22 e 28 sucessos?

print("\nEXERCÍCIO 7: Enxerto de plantas")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 8 - BINOMIAL
# ==========================================
# Contexto: Mutação genética
# Uma mutação ocorre com probabilidade 0.001 por gene.
# Analisamos 5000 genes. X = número de genes com mutação.
# Perguntas:
# a) Esta situação segue binomial? Por quê?
# b) P(nenhum gene mutado) = ?
# c) P(exatamente 5 genes mutados) = ?

print("\nEXERCÍCIO 8: Mutação genética")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 9 - BINOMIAL
# ==========================================
# Contexto: Teste de paternidade
# Um teste de paternidade tem 99.9% de precisão.
# Realizamos 50 testes independentes. X = número de resultados corretos.
# Perguntas:
# a) P(todos os testes corretos) = ?
# b) P(pelo menos 49 corretos) = ?
# c) Qual a média e variância esperadas?

print("\nEXERCÍCIO 9: Teste de paternidade")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 10 - BINOMIAL
# ==========================================
# Contexto: Eclosão de ovos de inseto
# Ovos de uma espécie de borboleta têm 70% de taxa de eclosão.
# Uma fêmea põe 40 ovos. X = número de ovos que eclodem.
# Perguntas:
# a) P(exatamente 30 eclodirem) = ?
# b) P(menos de 20 eclodirem) = ?
# c) Entre que valores temos 90% dos resultados esperados?

print("\nEXERCÍCIO 10: Eclosão de ovos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 11 - BINOMIAL
# ==========================================
# Contexto: Detecção de patógeno
# Um teste para detectar vírus em plantas tem 95% de sensibilidade.
# Testamos 100 plantas infectadas. X = número de testes positivos.
# Perguntas:
# a) P(todos os testes positivos) = ?
# b) P(pelo menos 90 positivos) = ?
# c) Qual a probabilidade de ter falsos negativos?

print("\nEXERCÍCIO 11: Detecção de patógeno")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 12 - BINOMIAL
# ==========================================
# Contexto: Polinização cruzada
# Em uma população de plantas, 35% das flores são polinizadas por abelhas.
# Observamos 60 flores. X = número polinizado por abelhas.
# Perguntas:
# a) P(exatamente 20 serem polinizadas por abelhas) = ?
# b) P(entre 15 e 25 serem polinizadas por abelhas) = ?
# c) Qual o coeficiente de variação?

print("\nEXERCÍCIO 12: Polinização cruzada")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 13 - BINOMIAL
# ==========================================
# Contexto: Regeneração de tecido
# Células-tronco têm 45% de chance de se diferenciarem corretamente.
# Cultivamos 80 células. X = número que se diferencia corretamente.
# Perguntas:
# a) P(exatamente metade se diferenciarem) = ?
# b) P(mais de 50 se diferenciarem) = ?
# c) Qual a probabilidade de sucesso estar entre 30-50?

print("\nEXERCÍCIO 13: Regeneração de tecido")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 14 - BINOMIAL
# ==========================================
# Contexto: Imunização de rebanho
# Uma vacina tem 88% de eficácia em bovinos.
# Vacinamos 200 animais. X = número imunizado efetivamente.
# Perguntas:
# a) P(todos ficarem imunizados) = ?
# b) P(pelo menos 170 ficarem imunizados) = ?
# c) Qual o intervalo que contém 95% dos resultados?

print("\nEXERCÍCIO 14: Imunização de rebanho")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 15 - BINOMIAL
# ==========================================
# Contexto: Brotação de sementes armazenadas
# Sementes armazenadas por 2 anos têm 65% de viabilidade.
# Testamos 150 sementes. X = número que brota.
# Perguntas:
# a) P(exatamente 100 brotarem) = ?
# b) P(menos de 90 brotarem) = ?
# c) Acima de que valor temos 10% dos resultados?

print("\nEXERCÍCIO 15: Brotação de sementes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 16 - BINOMIAL
# ==========================================
# Contexto: Sobrevivência pós-transplante
# Mudas transplantadas têm 72% de taxa de sobrevivência.
# Um viveiro transplanta 90 mudas. X = número que sobrevive.
# Perguntas:
# a) P(exatamente 60 sobreviverem) = ?
# b) P(entre 55 e 75 sobreviverem) = ?
# c) Qual a probabilidade de mortalidade ser maior que 35%?

print("\nEXERCÍCIO 16: Sobrevivência pós-transplante")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 17 - BINOMIAL
# ==========================================
# Contexto: Identificação de espécies
# Um taxonomista identifica corretamente 92% das espécies.
# Examina 75 espécimes. X = número identificado corretamente.
# Perguntas:
# a) P(identificar todas corretamente) = ?
# b) P(errar no máximo 3 identificações) = ?
# c) Qual o número esperado de erros?

print("\nEXERCÍCIO 17: Identificação de espécies")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 18 - BINOMIAL
# ==========================================
# Contexto: Fecundação in vitro
# Óvulos fertilizados in vitro têm 55% de chance de desenvolver.
# Um laboratório fertiliza 120 óvulos. X = número que se desenvolve.
# Perguntas:
# a) P(exatamente 70 se desenvolverem) = ?
# b) P(pelo menos 80 se desenvolverem) = ?
# c) Entre que valores temos 80% dos resultados?

print("\nEXERCÍCIO 18: Fecundação in vitro")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 19 - BINOMIAL
# ==========================================
# Contexto: Adesão a protocolo veterinário
# 78% dos veterinários seguem um novo protocolo.
# Pesquisamos 250 veterinários. X = número que segue o protocolo.
# Perguntas:
# a) P(exatamente 200 seguirem) = ?
# b) P(mais de 180 seguirem) = ?
# c) Qual a variabilidade esperada (desvio padrão)?

print("\nEXERCÍCIO 19: Adesão a protocolo")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 20 - BINOMIAL
# ==========================================
# Contexto: Expressão de gene marcador
# Um gene marcador é expresso em 25% das células transformadas.
# Analisamos 300 células. X = número com expressão do gene.
# Perguntas:
# a) P(exatamente 75 expressarem) = ?
# b) P(entre 60 e 90 expressarem) = ?
# c) Qual a probabilidade de eficiência ser menor que 20%?

print("\nEXERCÍCIO 20: Expressão de gene marcador")
# Complete o exercício aqui

# %% [markdown]
# # EXERCÍCIOS - DISTRIBUIÇÃO DE POISSON
#
#  Para cada exercício sobre distribuição de Poisson, você deve:
#  1. Identificar o parâmetro λ (lambda)
#  2. Verificar se satisfaz as condições da Poisson
#  3. Criar tabela da distribuição (valores 0 até λ+3σ)
#  4. Fazer gráfico da função de probabilidades
#  5. Fazer gráfico da função de distribuição acumulada
#  6. Calcular E[X] = λ e Var[X] = λ
#  7. Responder perguntas específicas sobre probabilidades

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

# ==========================================
# EXERCÍCIO 1 - POISSON
# ==========================================
# Contexto: Mutações em sequência de DNA
# Em uma sequência de 1000 bases, ocorrem em média 2.5 mutações.
# X = número de mutações observadas em uma sequência.
# Perguntas:
# a) P(nenhuma mutação) = ?
# b) P(exatamente 3 mutações) = ?
# c) P(mais de 5 mutações) = ?

print("EXERCÍCIO 1: Mutações em DNA")
lambda_val = 2.5
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 2 - POISSON
# ==========================================
# Contexto: Chegada de polinizadores
# Em uma flor, chegam em média 4.2 abelhas por hora.
# X = número de abelhas que chegam em 1 hora.
# Perguntas:
# a) P(nenhuma abelha chegar) = ?
# b) P(entre 3 e 6 abelhas chegarem) = ?
# c) Qual o número mais provável de abelhas?

print("\nEXERCÍCIO 2: Chegada de polinizadores")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 3 - POISSON
# ==========================================
# Contexto: Contagem de bactérias
# Em 1 mL de amostra, há em média 3.8 bactérias patogênicas.
# X = número de bactérias em 1 mL.
# Perguntas:
# a) P(amostra estar estéril) = ?
# b) P(encontrar pelo menos 5 bactérias) = ?
# c) Em 5 mL, quantas bactérias esperamos?

print("\nEXERCÍCIO 3: Contagem de bactérias")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 4 - POISSON
# ==========================================
# Contexto: Defeitos em cromossomos
# Cromossomos apresentam em média 1.8 quebras por preparação.
# X = número de quebras cromossômicas observadas.
# Perguntas:
# a) P(cromossomo íntegro) = ?
# b) P(exatamente 2 quebras) = ?
# c) P(mais de 4 quebras) = ?

print("\nEXERCÍCIO 4: Defeitos cromossômicos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 5 - POISSON
# ==========================================
# Contexto: Nascimento de gêmeos
# Em uma maternidade, nascem em média 0.8 pares de gêmeos por mês.
# X = número de partos gemelares em um mês.
# Perguntas:
# a) P(nenhum parto gemelar) = ?
# b) P(exatamente 1 parto gemelar) = ?
# c) P(3 ou mais partos gemelares) = ?

print("\nEXERCÍCIO 5: Nascimento de gêmeos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 6 - POISSON
# ==========================================
# Contexto: Parasitas em peixes
# Peixes de um lago têm em média 2.3 parasitas externos.
# X = número de parasitas em um peixe.
# Perguntas:
# a) P(peixe sem parasitas) = ?
# b) P(peixe com 1 a 3 parasitas) = ?
# c) Acima de quantos parasitas temos 5% dos peixes?

print("\nEXERCÍCIO 6: Parasitas em peixes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 7 - POISSON
# ==========================================
# Contexto: Divisões celulares
# Células em cultura se dividem em média 1.5 vezes por hora.
# X = número de divisões em 1 hora.
# Perguntas:
# a) P(nenhuma divisão) = ?
# b) P(exatamente 2 divisões) = ?
# c) Em 4 horas, qual o número esperado de divisões?

print("\nEXERCÍCIO 7: Divisões celulares")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 8 - POISSON
# ==========================================
# Contexto: Espécies raras em amostra
# Em levantamentos botânicos, encontramos em média 0.6 espécies raras por hectare.
# X = número de espécies raras em 1 hectare.
# Perguntas:
# a) P(não encontrar espécies raras) = ?
# b) P(encontrar pelo menos 2 espécies) = ?
# c) Em área de 10 hectares, quantas espécies raras esperamos?

print("\nEXERCÍCIO 8: Espécies raras")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 9 - POISSON
# ==========================================
# Contexto: Erros de sequenciamento
# Sequenciadores de DNA cometem em média 0.4 erros por 1000 bases.
# X = número de erros em sequência de 1000 bases.
# Perguntas:
# a) P(sequência perfeita) = ?
# b) P(exatamente 1 erro) = ?
# c) P(2 ou mais erros) = ?

print("\nEXERCÍCIO 9: Erros de sequenciamento")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 10 - POISSON
# ==========================================
# Contexto: Nódulos em raízes
# Leguminosas desenvolvem em média 5.2 nódulos de fixação por planta.
# X = número de nódulos em uma planta.
# Perguntas:
# a) P(planta sem nódulos) = ?
# b) P(entre 4 e 7 nódulos) = ?
# c) Qual a variância esperada?

print("\nEXERCÍCIO 10: Nódulos em raízes")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 11 - POISSON
# ==========================================
# Contexto: Tumores benignos
# Ratos de laboratório desenvolvem em média 1.2 tumores benignos durante a vida.
# X = número de tumores em um rato.
# Perguntas:
# a) P(rato sem tumores) = ?
# b) P(exatamente 2 tumores) = ?
# c) P(mais de 3 tumores) = ?

print("\nEXERCÍCIO 11: Tumores benignos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 12 - POISSON
# ==========================================
# Contexto: Crossing-over meiótico
# Durante a meiose, ocorrem em média 2.8 eventos de crossing-over por cromossomo.
# X = número de crossing-overs em um cromossomo.
# Perguntas:
# a) P(nenhum crossing-over) = ?
# b) P(exatamente 3 crossing-overs) = ?
# c) Qual o número modal de crossing-overs?

print("\nEXERCÍCIO 12: Crossing-over meiótico")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 13 - POISSON
# ==========================================
# Contexto: Predação de ninhos
# Ninhos de aves sofrem em média 0.9 ataques de predadores por estação.
# X = número de ataques a um ninho.
# Perguntas:
# a) P(ninho não ser atacado) = ?
# b) P(sofrer 2 ou mais ataques) = ?
# c) Em 20 ninhos, quantos ataques esperamos no total?

print("\nEXERCÍCIO 13: Predação de ninhos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 14 - POISSON
# ==========================================
# Contexto: Contaminação de cultura
# Culturas celulares se contaminam em média 0.3 vezes por semana.
# X = número de contaminações em uma semana.
# Perguntas:
# a) P(semana sem contaminação) = ?
# b) P(1 ou mais contaminações) = ?
# c) Em um mês (4 semanas), qual a probabilidade de não haver contaminação?

print("\nEXERCÍCIO 14: Contaminação de cultura")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 15 - POISSON
# ==========================================
# Contexto: Floração de cactus
# Cactus florescem em média 3.5 vezes por ano.
# X = número de florações em um ano.
# Perguntas:
# a) P(não florescer no ano) = ?
# b) P(florescer 5 ou mais vezes) = ?
# c) Qual o coeficiente de variação?

print("\nEXERCÍCIO 15: Floração de cactus")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 16 - POISSON
# ==========================================
# Contexto: Falhas em PCR
# Reações de PCR falham em média 0.7 vezes por 10 reações.
# X = número de falhas em 10 reações.
# Perguntas:
# a) P(todas as reações funcionarem) = ?
# b) P(exatamente 1 falha) = ?
# c) P(mais de 2 falhas) = ?

print("\nEXERCÍCIO 16: Falhas em PCR")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 17 - POISSON
# ==========================================
# Contexto: Descoberta de espécies novas
# Pesquisadores descobrem em média 2.1 espécies novas por expedição.
# X = número de espécies descobertas em uma expedição.
# Perguntas:
# a) P(não descobrir espécies novas) = ?
# b) P(descobrir entre 2 e 4 espécies) = ?
# c) Em 5 expedições, quantas espécies novas esperamos?

print("\nEXERCÍCIO 17: Descoberta de espécies")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 18 - POISSON
# ==========================================
# Contexto: Mortalidade de alevinos
# Alevinos morrem em média 4.6 por tanque por semana.
# X = número de mortes em um tanque por semana.
# Perguntas:
# a) P(nenhuma morte) = ?
# b) P(5 ou 6 mortes) = ?
# c) Acima de quantas mortes temos 10% dos casos?

print("\nEXERCÍCIO 18: Mortalidade de alevinos")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 19 - POISSON
# ==========================================
# Contexto: Mutações induzidas por radiação
# Radiação induz em média 1.9 mutações por gene por Gray.
# X = número de mutações em um gene após 1 Gray.
# Perguntas:
# a) P(gene não mutar) = ?
# b) P(exatamente 3 mutações) = ?
# c) Após 2 Gray, quantas mutações esperamos?

print("\nEXERCÍCIO 19: Mutações por radiação")
# Complete o exercício aqui

# ==========================================
# EXERCÍCIO 20 - POISSON
# ==========================================
# Contexto: Brotos adventícios
# Plantas em cultura de tecido produzem em média 6.8 brotos adventícios.
# X = número de brotos em uma planta.
# Perguntas:
# a) P(nenhum broto) = ?
# b) P(entre 5 e 10 brotos) = ?
# c) Qual a probabilidade de produção acima da média?

print("\nEXERCÍCIO 20: Brotos adventícios")
# Complete o exercício aqui
